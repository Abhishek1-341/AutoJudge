# %%
import numpy as np
import pandas as pd
#import plotly.express as px
#import xgboost as xgb
import optuna
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
df = pd.read_json("problems_data.jsonl", lines=True)

def build_full_text(df):
    text_cols = ['title', 'description', 'input_description', 'output_description']
    return (
        df[text_cols]
        .fillna('')
        .agg(' '.join, axis=1)
        .str.lower()
        .str.replace(r'\s+', ' ', regex=True)
        .str.strip()
    )

df['full_text'] = build_full_text(df)

le = LabelEncoder()
df['problem_class_enc'] = le.fit_transform(df['problem_class'])
print(le.classes_)

y_cls = df['problem_class_enc']
y_reg = df['problem_score']
# Out:
# ['easy' 'hard' 'medium']

# %%
def extract_stat_features(df):
    text = df['full_text']

    features = pd.DataFrame({
        'char_len': text.str.len(),
        'word_len': text.str.split().str.len(),
        'sentence_count': text.str.count(r'[.!?]') + 1,

        'digit_count': text.str.count(r'\d'),
        'math_symbol_count': text.str.count(r'[\+\-\*/=<>\^]'),

        # NEW (important)
        'log_char_len': np.log1p(text.str.len()),
        'log_word_len': np.log1p(text.str.split().str.len()),

        'constraint_count': text.str.count(r'(<=|>=|<|>)'),
        'power_count': text.str.count(r'\^'),
        'big_o_count': text.str.count(r'o\('),

        'newline_count': text.str.count(r'\n'),
        'colon_count': text.str.count(':'),

        'avg_word_len': text.str.len() / (text.str.split().str.len() + 1),
    })

    return features

KEYWORDS = {
    # Core paradigms
    'dp': ['dp', 'dynamic programming'],
    'graph': ['graph', 'tree', 'dag'],
    'greedy': ['greedy'],
    'binary_search': ['binary search'],
    'two_pointers': ['two pointers'],

    # Data structures
    'segment_tree': ['segment tree'],
    'fenwick': ['fenwick', 'bit'],
    'heap': ['heap', 'priority queue'],
    'disjoint_set': ['dsu', 'union find'],

    # Math / advanced
    'modulo': ['mod', 'modulo'],
    'combinatorics': ['combination', 'permutation'],
    'probability': ['probability', 'expected'],

    # Geometry / strings
    'geometry': ['geometry', 'convex'],
    'string_algo': ['kmp', 'z', 'suffix'],

    # Brute force indicators
    'bruteforce': ['brute', 'naive']
}

def extract_keyword_features(df):
    text = df['full_text']
    feats = {}

    for k, patterns in KEYWORDS.items():
        feats[f'{k}_present'] = text.apply(
            lambda x: any(p in x for p in patterns)
        ).astype(int)

        feats[f'{k}_count'] = text.apply(
            lambda x: sum(p in x for p in patterns)
        )

    return pd.DataFrame(feats)

# %%
X_stat = extract_stat_features(df)
X_kw = extract_keyword_features(df)

# %% [markdown]
# ## classification

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack, csr_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score

# %%
tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    min_df=5,
    max_features=30000)
X_tfidf = tfidf.fit_transform(df['full_text'])

X_cls = csr_matrix(hstack([
    X_tfidf,
    X_stat.values,
    X_kw.values
]))

# %%
def logreg_objective(trial):
    C = trial.suggest_float("C", 1e-4, 10.0, log=True)
    class_weight = trial.suggest_categorical("class_weight", [None, "balanced"])

    model = Pipeline([
        ('scaler', StandardScaler(with_mean=False)),  # sparse-safe
        ('clf', LogisticRegression(
            C=C,
            solver='lbfgs',
            penalty='l2',
            max_iter=3000,
            class_weight=class_weight,
            n_jobs=-1
        ))
    ])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    f1s = []

    for tr, va in skf.split(X_cls, y_cls):
        model.fit(X_cls[tr], y_cls[tr])
        preds = model.predict(X_cls[va])
        f1s.append(f1_score(y_cls[va], preds, average='macro'))

    return np.mean(f1s)

study = optuna.create_study(direction="maximize")
study.optimize(logreg_objective, n_trials=100)

print("Best macro-F1:", study.best_value)
print("Best params:", study.best_params)
# Out:
# [I 2026-01-06 14:04:04,161] A new study created in memory with name: no-name-81319586-d8c6-483f-a58a-21b3ca7dbeb9
# [I 2026-01-06 14:04:16,517] Trial 0 finished with value: 0.4299453523375288 and parameters: {'C': 0.791562070704174, 'class_weight': None}. Best is trial 0 with value: 0.4299453523375288.
# [I 2026-01-06 14:04:28,471] Trial 1 finished with value: 0.4279807186502861 and parameters: {'C': 0.15925810768385337, 'class_weight': None}. Best is trial 0 with value: 0.4299453523375288.
# [I 2026-01-06 14:04:40,043] Trial 2 finished with value: 0.4249646920020217 and parameters: {'C': 0.03920712171214759, 'class_weight': None}. Best is trial 0 with value: 0.4299453523375288.
# [I 2026-01-06 14:04:51,230] Trial 3 finished with value: 0.4409644604356172 and parameters: {'C': 0.00981933866178707, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.4409644604356172.
# [I 2026-01-06 14:05:03,787] Trial 4 finished with value: 0.4068988258607448 and parameters: {'C': 0.00016732722621584583, 'class_weight': None}. Best is trial 3 with value: 0.4409644604356172.
# [I 2026-01-06 14:05:17,471] Trial 5 finished with value: 0.43915007356965896 and parameters: {'C': 0.4742354338349405, 'class_weight': 'balanced'}. Best is trial 3 with value: 0.4409644604356172.
# [I 2026-01-06 14:05:29,038] Trial 6 finished with value: 0.4239602432565082 and parameters: {'C': 0.03020819851189085, 'class_weight': None}. Best is trial 3 with value: 0.4409644604356172.
# [I 2026-01-06 14:05:39,696] Trial 7 finished with value: 0.4246765428369336 and parameters: {'C': 0.010272141372961193, 'class_weight': None}. Best is trial 3 with value: 0.4409644604356172.
# [I 2026-01-06 14:05:50,368] Trial 8 finished with value: 0.4526058537542509 and parameters: {'C': 0.00011291596730243798, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.4526058537542509.
# [I 2026-01-06 14:06:02,797] Trial 9 finished with value: 0.4278945560510626 and parameters: {'C': 0.8298313996871558, 'class_weight': None}. Best is trial 8 with value: 0.4526058537542509.
# [I 2026-01-06 14:06:14,854] Trial 10 finished with value: 0.45052382488093257 and parameters: {'C': 0.00023151185858605878, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.4526058537542509.
# [I 2026-01-06 14:06:26,488] Trial 11 finished with value: 0.4516324775202126 and parameters: {'C': 0.00011668203065853076, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.4526058537542509.
# [I 2026-01-06 14:06:41,319] Trial 12 finished with value: 0.44597614664260155 and parameters: {'C': 0.000996818015916624, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.4526058537542509.
# [I 2026-01-06 14:06:56,744] Trial 13 finished with value: 0.4454614853589837 and parameters: {'C': 0.0013357267861330603, 'class_weight': 'balanced'}. Best is trial 8 with value: 0.4526058537542509.
 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:21:41,812] Trial 85 finished with value: 0.4543619690407594 and parameters: {'C': 0.00010028325855900945, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:21:54,626] Trial 86 finished with value: 0.43778621499165177 and parameters: {'C': 0.2213679377839225, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:22:05,823] Trial 87 finished with value: 0.45347458005100083 and parameters: {'C': 0.00014798082642108668, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:22:18,489] Trial 88 finished with value: 0.447710790783957 and parameters: {'C': 0.0003112592467951851, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:22:29,328] Trial 89 finished with value: 0.45025618979062737 and parameters: {'C': 0.0002178616239761114, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:22:40,331] Trial 90 finished with value: 0.45388730868943494 and parameters: {'C': 0.00014045629495661207, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:22:50,525] Trial 91 finished with value: 0.45324481665329885 and parameters: {'C': 0.0001066255253157042, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:23:00,855] Trial 92 finished with value: 0.45389481192789727 and parameters: {'C': 0.00010191162403164634, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:23:12,089] Trial 93 finished with value: 0.45388730868943494 and parameters: {'C': 0.00014038403061168844, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:23:23,882] Trial 94 finished with value: 0.4509551211005247 and parameters: {'C': 0.00020973845580562128, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:23:38,072] Trial 95 finished with value: 0.44342405732276 and parameters: {'C': 0.006295549193429798, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:23:51,066] Trial 96 finished with value: 0.44594453541353635 and parameters: {'C': 0.0004106980521741223, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:24:02,320] Trial 97 finished with value: 0.39740694013865474 and parameters: {'C': 0.0001336009414078768, 'class_weight': None}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:24:12,685] Trial 98 finished with value: 0.4543644365785637 and parameters: {'C': 0.00010134688543248654, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# [I 2026-01-06 14:24:24,864] Trial 99 finished with value: 0.45201922416518736 and parameters: {'C': 0.00018303297887523935, 'class_weight': 'balanced'}. Best is trial 38 with value: 0.4548674007084618.
# Best macro-F1: 0.4548674007084618
# Best params: {'C': 0.00010021197815889274, 'class_weight': 'balanced'}

# %%
X_tr, X_te, y_tr, y_te = train_test_split(
    X, y_cls,
    test_size=0.2,
    random_state=42,
    stratify=y_cls
)

final_model = Pipeline([
    ('scaler', StandardScaler(with_mean=False)),
    ('clf', LogisticRegression(
        **study.best_params,
        solver='lbfgs',
        penalty='l2',
        max_iter=3000,
        n_jobs=-1
    ))
])

final_model.fit(X_tr, y_tr)
y_pred = final_model.predict(X_te)

print(classification_report(y_te, y_pred, target_names=le.classes_))
print(confusion_matrix(y_te, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         easy       0.52      0.37      0.44       153
#         hard       0.56      0.64      0.60       389
#       medium       0.37      0.35      0.36       281
#
#     accuracy                           0.49       823
#    macro avg       0.48      0.46      0.46       823
# weighted avg       0.49      0.49      0.49       823
#
# [[ 57  38  58]
#  [ 27 250 112]
#  [ 25 157  99]]

# %%
print(study.best_params)
# Out:
# {'C': 0.00010021197815889274, 'class_weight': 'balanced'}

# %% [markdown]
# ## regression

# %%
X_reg = csr_matrix(hstack([X_tfidf,X_stat.values,X_kw.values]))
y = y_reg.values

# %%
def ridge_objective(trial):
    alpha = trial.suggest_float('alpha', 1e-4, 1e4, log=True)
    fit_intercept = trial.suggest_categorical('fit_intercept', [True, False])

    model = Ridge(alpha=alpha, fit_intercept=fit_intercept)
    model = Pipeline([
        ('scaler', StandardScaler(with_mean=False)),  # sparse-safe
        ('reg', Ridge(alpha=alpha, fit_intercept=fit_intercept))
    ])

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    rmses = []

    for tr, va in kf.split(X_reg):
        model.fit(X_reg[tr], y[tr])
        preds = model.predict(X_reg[va])
        rmses.append(mean_squared_error(y[va], preds)**0.5)

    return np.mean(rmses)


study = optuna.create_study(direction='minimize')
study.optimize(ridge_objective, n_trials=100)

print("Best RMSE:", study.best_value)
print("Best Params:", study.best_params)
# Out:
# [I 2026-01-06 15:18:39,494] A new study created in memory with name: no-name-ed34c832-69af-4319-8859-70622e8c11dd
# [I 2026-01-06 15:18:40,806] Trial 0 finished with value: 2.1655668909094032 and parameters: {'alpha': 310.2611875038261, 'fit_intercept': False}. Best is trial 0 with value: 2.1655668909094032.
# [I 2026-01-06 15:18:44,484] Trial 1 finished with value: 5.9529311089774 and parameters: {'alpha': 0.03378160874182457, 'fit_intercept': True}. Best is trial 0 with value: 2.1655668909094032.
# [I 2026-01-06 15:18:48,758] Trial 2 finished with value: 73.91593972231126 and parameters: {'alpha': 0.00015050866556205674, 'fit_intercept': False}. Best is trial 0 with value: 2.1655668909094032.
# [I 2026-01-06 15:18:51,714] Trial 3 finished with value: 2.238078948644084 and parameters: {'alpha': 1.4880507139312662, 'fit_intercept': False}. Best is trial 0 with value: 2.1655668909094032.
# [I 2026-01-06 15:18:52,156] Trial 4 finished with value: 2.0626434461939285 and parameters: {'alpha': 8500.352575084657, 'fit_intercept': False}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:18:54,654] Trial 5 finished with value: 2.2278112197191824 and parameters: {'alpha': 3.833902106956257, 'fit_intercept': False}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:18:57,419] Trial 6 finished with value: 2.222933914393047 and parameters: {'alpha': 9.965076916147652, 'fit_intercept': True}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:01,694] Trial 7 finished with value: 2.717205550956278 and parameters: {'alpha': 0.14325501279758077, 'fit_intercept': True}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:05,026] Trial 8 finished with value: 2.205509096285239 and parameters: {'alpha': 32.46943361380142, 'fit_intercept': True}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:08,228] Trial 9 finished with value: 4.683810217107477 and parameters: {'alpha': 0.030157556701388373, 'fit_intercept': False}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:08,981] Trial 10 finished with value: 2.1386613363144287 and parameters: {'alpha': 1302.7217140124578, 'fit_intercept': False}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:09,420] Trial 11 finished with value: 2.069657827857624 and parameters: {'alpha': 7404.776839883754, 'fit_intercept': False}. Best is trial 4 with value: 2.0626434461939285.
# [I 2026-01-06 15:19:09,849] Trial 12 finished with value: 2.055607882489538 and parameters: {'alpha': 9771.306627982316, 'fit_intercept': False}. Best is trial 12 with value: 2.055607882489538.
# [I 2026-01-06 15:19:10,294] Trial 13 finished with value: 2.068466498030966 and parameters: {'alpha': 7580.057110868964, 'fit_intercept': False}. Best is trial 12 with value: 2.055607882489538.
# [I 2026-01-06 15:19:11,808] Trial 14 finished with value: 2.17543554787907 and parameters: {'alpha': 152.82561514219913, 'fit_intercept': False}. Best is trial 12 with value: 2.055607882489538.
# [I 2026-01-06 15:19:12,624] Trial 15 finished with value: 2.148400610360009 and parameters: {'alpha': 852.8633338814436, 'fit_intercept': False}. Best is trial 12 with value: 2.055607882489538.
# [I 2026-01-06 15:19
 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:29,429] Trial 74 finished with value: 2.081097016603935 and parameters: {'alpha': 5901.0489032054, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:30,355] Trial 75 finished with value: 2.1217054703547222 and parameters: {'alpha': 2291.3099231979645, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:35,745] Trial 76 finished with value: 2.448680047394093 and parameters: {'alpha': 0.16264314485715864, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:37,025] Trial 77 finished with value: 2.154296922266911 and parameters: {'alpha': 627.4130330537241, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:37,625] Trial 78 finished with value: 2.056011469674403 and parameters: {'alpha': 9693.011086616476, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:38,674] Trial 79 finished with value: 2.1408397264042685 and parameters: {'alpha': 1194.557378296241, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:41,677] Trial 80 finished with value: 2.208087120924532 and parameters: {'alpha': 16.823271685100693, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:42,103] Trial 81 finished with value: 2.057326224595566 and parameters: {'alpha': 9441.594405816684, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:42,639] Trial 82 finished with value: 2.104075974630084 and parameters: {'alpha': 3604.661005633798, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:43,109] Trial 83 finished with value: 2.0795459241684298 and parameters: {'alpha': 6087.109371601916, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:43,575] Trial 84 finished with value: 2.0770953528054523 and parameters: {'alpha': 6392.708621782171, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:44,130] Trial 85 finished with value: 2.1088199821567715 and parameters: {'alpha': 3218.4653629216314, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:44,965] Trial 86 finished with value: 2.128279333011406 and parameters: {'alpha': 1878.3343671796144, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:46,191] Trial 87 finished with value: 2.0691734739583856 and parameters: {'alpha': 9708.820407503306, 'fit_intercept': True}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:47,248] Trial 88 finished with value: 2.1463560934500654 and parameters: {'alpha': 939.7255201453423, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:47,704] Trial 89 finished with value: 2.0762501184193836 and parameters: {'alpha': 6501.039813253766, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:48,243] Trial 90 finished with value: 2.1040493871142765 and parameters: {'alpha': 3606.9435178314234, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:48,698] Trial 91 finished with value: 2.0775967738092085 and parameters: {'alpha': 6329.188572607828, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:49,354] Trial 92 finished with value: 2.127988504449034 and parameters: {'alpha': 1895.355943749907, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:49,765] Trial 93 finished with value: 2.0585289877065716 and parameters: {'alpha': 9218.721012509679, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:50,324] Trial 94 finished with value: 2.1068372950067578 and parameters: {'alpha': 3376.633437679361, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:53,579] Trial 95 finished with value: 6.9166254188178 and parameters: {'alpha': 0.01709422116016816, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:54,041] Trial 96 finished with value: 2.0766334742460804 and parameters: {'alpha': 6451.708535390382, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:54,620] Trial 97 finished with value: 2.1173908806483515 and parameters: {'alpha': 2583.4327043417334, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:55,215] Trial 98 finished with value: 2.068317553662017 and parameters: {'alpha': 9889.468648113321, 'fit_intercept': True}. Best is trial 63 with value: 2.0547407176407386.
# [I 2026-01-06 15:20:56,334] Trial 99 finished with value: 2.16216653993932 and parameters: {'alpha': 389.2949008271341, 'fit_intercept': False}. Best is trial 63 with value: 2.0547407176407386.
# Best RMSE: 2.0547407176407386
# Best Params: {'alpha': 9942.524780082125, 'fit_intercept': False}

# %% [markdown]
# ## version check

# %%
import sklearn, joblib


print('numpy',numpy.__version__)
print("sklearn:", sklearn.__version__)
print("pandas",pandas.__version__)
print("scipy",scipy.__version__)
print("joblib:", joblib.__version__)
# Out:
# numpy 2.0.2
# sklearn: 1.6.1
# pandas 2.2.2
# scipy 1.16.3
# joblib: 1.5.3

# %%
34
# Out:
# 34
